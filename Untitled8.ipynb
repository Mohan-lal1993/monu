# %%
import pandas as pd

# %%
pokemon_names= pd.read_csv("pokemon.csv", usecols=["Pokemon"], squeeze=True)
pokemon_type= pd.read_csv("pokemon.csv", index_col="Pokemon", squeeze=True).to_dict()

# %%
pokemon_names
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
pokemon_type
# Out:
# {'Bulbasaur': 'Grass',
#  'Ivysaur': 'Grass',
#  'Venusaur': 'Grass',
#  'Charmander': 'Fire',
#  'Charmeleon': 'Fire',
#  'Charizard': 'Fire',
#  'Squirtle': 'Water',
#  'Wartortle': 'Water',
#  'Blastoise': 'Water',
#  'Caterpie': 'Bug',
#  'Metapod': 'Bug',
#  'Butterfree': 'Bug',
#  'Weedle': 'Bug',
#  'Kakuna': 'Bug',
#  'Beedrill': 'Bug',
#  'Pidgey': 'Normal',
#  'Pidgeotto': 'Normal',
#  'Pidgeot': 'Normal',
#  'Rattata': 'Normal',
#  'Raticate': 'Normal',
#  'Spearow': 'Normal',
#  'Fearow': 'Normal',
#  'Ekans': 'Poison',
#  'Arbok': 'Poison',
#  'Pikachu': 'Electric',
#  'Raichu': 'Electric',
#  'Sandshrew': 'Ground',
#  'Sandslash': 'Ground',
#  'Nidoran': 'Poison',
#  'Nidorina': 'Poison',
#  'Nidoqueen': 'Poison',
#  'Nidoran♂': 'Poison',
#  'Nidorino': 'Poison',
#  'Nidoking': 'Poison',
#  'Clefairy': 'Fairy',
#  'Clefable': 'Fairy',
#  'Vulpix': 'Fire',
#  'Ninetales': 'Fire',
#  'Jigglypuff': 'Normal',
#  'Wigglytuff': 'Normal',
#  'Zubat': 'Poison',
# ...

# %%
pokemon_names.map(pokemon_type)
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 3          Fire
# 4          Fire
# 5          Fire
# 6         Water
# 7         Water
# 8         Water
# 9           Bug
# 10          Bug
# 11          Bug
# 12          Bug
# 13          Bug
# 14          Bug
# 15       Normal
# 16       Normal
# 17       Normal
# 18       Normal
# 19       Normal
# 20       Normal
# 21       Normal
# 22       Poison
# 23       Poison
# 24     Electric
# 25     Electric
# 26       Ground
# 27       Ground
# 28       Poison
# 29       Poison
#          ...
# 691       Water
# 692       Water
# 693    Electric
# 694    Electric
# 695        Rock
# 696        Rock
# 697        Rock
# 698        Rock
# 699       Fairy
# 700    Fighting
# 701    Electric
# 702        Rock
# 703      Dragon
# 704      Dragon
# 705      Dragon
# 706       Steel
# 707       Ghost
# 708       Ghost
# 709       Ghost
# 710       Ghost
# 711         Ice
# 712         Ice
# 713      Flying
# 714      Flying
# ...

# %% [markdown]
# # Data Frames

# %%
nba=pd.read_csv("nba.csv")

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.tail(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.info
# Out:
# <bound method DataFrame.info of                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# # Difference between Share and Map method

# %%
rev = pd.read_csv("revenue.csv", index_col = "Date")

# %%
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
rev.sum(axis=1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis="columns")
output=None

# %% [markdown]
# # Select one column from Data Frame

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.Name
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
nba.Salary
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
# 5      90.0
# 6      55.0
# 7      41.0
# 8      12.0
# 9      36.0
# 10      7.0
# 11      4.0
# 12     11.0
# 13     13.0
# 14     44.0
# 15     44.0
# 16     22.0
# 17     21.0
# 18     24.0
# 19      2.0
# 20     10.0
# 21      6.0
# 22      0.0
# 23     11.0
# 24      1.0
# 25     33.0
# 26     41.0
# 27     14.0
# 28     15.0
# 29     30.0
#        ...
# 428     8.0
# 429     5.0
# 430    23.0
# 431    17.0
# 432     4.0
# 433     9.0
# 434    35.0
# 435    11.0
# 436     0.0
# 437     3.0
# 438    44.0
# 439    24.0
# 440     2.0
# 441    21.0
# 442    33.0
# 443     3.0
# 444    10.0
# 445    11.0
# 446    15.0
# 447    27.0
# 448    20.0
# 449     5.0
# 450     2.0
# 451    23.0
# 452    41.0
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba.Number
nba.Salary
nba.Name
output=None

# %%
type(nba["Name"])
# Out:
# pandas.core.series.Series

# %%
nba["Name"].head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
nba[["Name","Salary"]].tail(8)
# Out:
#               Name     Salary
# 450     Joe Ingles  2050000.0
# 451  Chris Johnson   981348.0
# 452     Trey Lyles  2239800.0
# 453   Shelvin Mack  2433333.0
# 454      Raul Neto   900000.0
# 455   Tibor Pleiss  2900000.0
# 456    Jeff Withey   947276.0
# 457            NaN        NaN

# %%
select = ["Salary","Name", "Number"]

# %%
nba[select]
# Out:
#          Salary                     Name  Number
# 0     7730337.0            Avery Bradley     0.0
# 1     6796117.0              Jae Crowder    99.0
# 2           NaN             John Holland    30.0
# 3     1148640.0              R.J. Hunter    28.0
# 4     5000000.0            Jonas Jerebko     8.0
# 5    12000000.0             Amir Johnson    90.0
# 6     1170960.0            Jordan Mickey    55.0
# 7     2165160.0             Kelly Olynyk    41.0
# 8     1824360.0             Terry Rozier    12.0
# 9     3431040.0             Marcus Smart    36.0
# 10    2569260.0          Jared Sullinger     7.0
# 11    6912869.0            Isaiah Thomas     4.0
# 12    3425510.0              Evan Turner    11.0
# 13    1749840.0              James Young    13.0
# 14    2616975.0             Tyler Zeller    44.0
# 15    3425510.0         Bojan Bogdanovic    44.0
# 16     845059.0             Markel Brown    22.0
# 17    1500000.0          Wayne Ellington    21.0
# ...

# %% [markdown]
# # Add new column to Data Frame

# %%
nba["Salary"]
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
nba.insert(3, column="Sports", value="Basketball")

# %%
nba
# Out:
#                         Name                    Team  Number      Sports  \
# 0              Avery Bradley          Boston Celtics     0.0  Basketball
# 1                Jae Crowder          Boston Celtics    99.0  Basketball
# 2               John Holland          Boston Celtics    30.0  Basketball
# 3                R.J. Hunter          Boston Celtics    28.0  Basketball
# 4              Jonas Jerebko          Boston Celtics     8.0  Basketball
# 5               Amir Johnson          Boston Celtics    90.0  Basketball
# 6              Jordan Mickey          Boston Celtics    55.0  Basketball
# 7               Kelly Olynyk          Boston Celtics    41.0  Basketball
# 8               Terry Rozier          Boston Celtics    12.0  Basketball
# 9               Marcus Smart          Boston Celtics    36.0  Basketball
# 10           Jared Sullinger          Boston Celtics     7.0  Basketball
# 11             Isaiah Thomas          Boston Celtics     4.0  Basketball
# ...

# %%
nba.insert(7, column="League", value="National Basketball Association")
# Out:
#                         Name                    Team  Number       Sport  \
# 0              Avery Bradley          Boston Celtics     0.0  Basketball
# 1                Jae Crowder          Boston Celtics    99.0  Basketball
# 2               John Holland          Boston Celtics    30.0  Basketball
# 3                R.J. Hunter          Boston Celtics    28.0  Basketball
# 4              Jonas Jerebko          Boston Celtics     8.0  Basketball
# 5               Amir Johnson          Boston Celtics    90.0  Basketball
# 6              Jordan Mickey          Boston Celtics    55.0  Basketball
# 7               Kelly Olynyk          Boston Celtics    41.0  Basketball
# 8               Terry Rozier          Boston Celtics    12.0  Basketball
# 9               Marcus Smart          Boston Celtics    36.0  Basketball
# 10           Jared Sullinger          Boston Celtics     7.0  Basketball
# 11             Isaiah Thomas          Boston Celtics     4.0  Basketball
# ...

# %%
nba
